# %% [markdown]
# # Depression Adverse Event Table Notebook

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

import os
import time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Read in Tables

# %%
unique_ae = pd.read_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/distinct_reported_events.csv')

# %%
smq_mapped = pd.read_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/smq_edited.csv')

# %%
smq_mapped.head()
# Out:
#    Row ID LLT/PT Term  LLT/PT Code                  PT
# 0       0           V          NaN                 NaN
# 1       1           K   10023271.0     Blood potassium
# 2       2          PE   10034191.0  Pulmonary embolism
# 3       3          GI          NaN                 NaN
# 4       4          ER          NaN                 NaN

# %%
trial_by_ae = pd.read_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/subset_adverse_events files/depression_subset_adverse_events.csv', index_col=0)

# %%
trial_by_ae.head()
# Out:
#         nct_id           id                                     adverse_events
# 1  NCT03315208  121187683.0  {relapsetosubstancesresultingininpatienttreatm...
# 2  NCT03315208  121187684.0  {relapsetosubstancesresultingininpatienttreatm...
# 3  NCT03315208  121187685.0  {relapsetosubstancesresultingininpatienttreatm...
# 4  NCT03315208  121187686.0  {relapsetosubstancesresultinginemergencydepart...
# 5  NCT03315208  121187687.0  {relapsetosubstancesresultinginemergencydepart...

# %%
unique_id = pd.DataFrame(trial_by_ae['id'].unique(), columns = ['id'])

# %%
unique_id.head()
# Out:
#             id
# 0  121187683.0
# 1  121187684.0
# 2  121187685.0
# 3  121187686.0
# 4  121187687.0

# %%
unique_ae_case = pd.DataFrame(trial_by_ae['adverse_events'].unique(), columns = ['lower'])
unique_ae_case['lower'] = unique_ae_case['lower'].str.slice(1,-1,1)

# %%
unique_ae_case.head()
# Out:
#                                                lower
# 0   relapsetosubstancesresultingininpatienttreatment
# 1  relapsetosubstancesresultinginemergencydepartm...
# 2  activesuicidalideationwithplanresultingininpat...
# 3  activesuicidalideationwithplanwithoutinpatient...
# 4  increaseinpsychoticsymptomsresultingininpatien...

# %%
unique_ae = unique_ae_case.merge(unique_ae, how='inner', on='lower')

# %%
unique_ae.shape, unique_id.shape, smq_mapped.shape, trial_by_ae.shape
# Out:
# ((8392, 2), (28056, 1), (101145, 4), (28156, 3))

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ## Sort for analysis

# %%
unique_ae.sort_values(by='adverse_event_term', key=lambda x: x.str.len(), inplace=True)

# %% [markdown]
# ## Drop duplicates and NaN values

# %%
unique_ae.drop_duplicates('lower', inplace=True)
unique_ae.dropna(axis=0, inplace=True)
unique_ae.reset_index(drop=True, inplace=True)
smq_mapped.drop('Row ID', axis=1, inplace=True)

# %%
trial_by_ae.dropna(axis=0, inplace=True)
trial_by_ae.reset_index(drop=True, inplace=True)

# %%
term_hits = pd.DataFrame(smq_mapped.dropna(axis=0))

# %%
unique_ae.shape, smq_mapped.shape, term_hits.shape, trial_by_ae.shape, unique_id.shape
# Out:
# ((2432, 2), (101145, 3), (24767, 3), (28055, 3), (28056, 1))

# %%
unique_ae.head()
# Out:
#   lower adverse_event_term
# 0   flu                FLU
# 1   tic                Tic
# 2   eye                Eye
# 3   ear                ear
# 4  mass               mass

# %%
ae_lookup_df = unique_ae.merge(term_hits, how='inner', left_on='adverse_event_term', right_on='LLT/PT Term')

# %%
ae_lookup_df.head()
# Out:
#    lower adverse_event_term LLT/PT Term  LLT/PT Code         PT
# 0    flu                FLU         FLU   10016790.0  Influenza
# 1    tic                Tic         Tic   10043833.0        Tic
# 2   rash               rash        rash   10037844.0       Rash
# 3   pain               pain        pain   10033371.0       Pain
# 4  manic              Manic       Manic   10026752.0      Mania

# %%
ae_lookup_df.shape
# Out:
# (547, 5)

# %% [markdown]
# ## Create Final Table

# %%
final_ae = pd.DataFrame(columns=ae_lookup_df['PT'].unique(), index=trial_by_ae['id'])

# %%
final_ae.shape
# Out:
# (28055, 479)

# %%
final_ae.head()
# Out:
#             Influenza  Tic Rash Pain Mania Crime Anger Wound Dizziness  \
# id
# 121187683.0       NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN       NaN
# 121187684.0       NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN       NaN
# 121187685.0       NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN       NaN
# 121187686.0       NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN       NaN
# 121187687.0       NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN       NaN
#
#             Muscle spasms  ... Blood pressure diastolic decreased  \
# id                         ...
# 121187683.0           NaN  ...                                NaN
# 121187684.0           NaN  ...                                NaN
# 121187685.0           NaN  ...                                NaN
# 121187686.0           NaN  ...                                NaN
# 121187687.0           NaN  ...                                NaN
#
#             Human chorionic gonadotropin  \
# id
# 121187683.0                          NaN
# 121187684.0                          NaN
# 121187685.0                          NaN
# 121187686.0                          NaN
# 121187687.0                          NaN
#
#             Electrocardiogram ST segment abnormal  \
# id
# 121187683.0                                   NaN
# 121187684.0                                   NaN
# 121187685.0                                   NaN
# 121187686.0                                   NaN
# 121187687.0                                   NaN
#
#             Tuberculosis of peripheral lymph nodes  \
# id
# 121187683.0                                    NaN
# 121187684.0                                    NaN
# 121187685.0                                    NaN
# 121187686.0                                    NaN
# 121187687.0                                    NaN
#
#             Eye complication associated with device  \
# id
# 121187683.0                                     NaN
# 121187684.0                                     NaN
# 121187685.0                                     NaN
# 121187686.0                                     NaN
# 121187687.0                                     NaN
#
#             Blood thyroid stimulating hormone decreased  \
# id
# 121187683.0                                         NaN
# 121187684.0                                         NaN
# 121187685.0                                         NaN
# 121187686.0                                         NaN
# 121187687.0                                         NaN
#
#             Pancreatic neuroendocrine tumour metastatic Insomnia  \
# id
# 121187683.0                                         NaN      NaN
# 121187684.0                                         NaN      NaN
# 121187685.0                                         NaN      NaN
# 121187686.0                                         NaN      NaN
# 121187687.0                                         NaN      NaN
#
#             Adjustment disorder with disturbance of conduct  \
# id
# 121187683.0                                             NaN
# 121187684.0                                             NaN
# 121187685.0                                             NaN
# 121187686.0                                             NaN
# 121187687.0                                             NaN
#
#             Adjustment disorder with mixed anxiety and depressed mood
# id
# 121187683.0                                                NaN
# 121187684.0                                                NaN
# 121187685.0                                                NaN
# 121187686.0                                                NaN
# 121187687.0                                                NaN
#
# [5 rows x 479 columns]

# %%
for i in range(trial_by_ae.shape[0]):
  check = 0
  ind = trial_by_ae['id'][i]
  term = trial_by_ae['adverse_events'][i][1:-1]
  if (ae_lookup_df['lower'] == term).any():
    adverse_event = ae_lookup_df.loc[ae_lookup_df['lower'] == term]
    adverse_event = adverse_event['PT'].values[0]
    final_ae.loc[ind, adverse_event] = 1
    check = 1
  if check == 0:
    final_ae.drop(ind)

# %%
final_ae.shape

# %%
final_ae.dropna(axis=0, how='all', inplace=True)
final_ae.fillna(0, inplace=True)
final_ae.shape

# %%
depression_ae_table = final_ae

# %%
depression_ae_table.to_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/Final AE Tables/depression_ae_table.csv')

# %% [markdown]
# # Anxiety Adverse Event Table Notebook

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

import os
import time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Read in Tables

# %%
unique_ae = pd.read_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/distinct_reported_events.csv')

# %%
smq_mapped = pd.read_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/smq_edited.csv')

# %%
smq_mapped.head()
# Out:
#    Row ID LLT/PT Term  LLT/PT Code                  PT
# 0       0           V          NaN                 NaN
# 1       1           K   10023271.0     Blood potassium
# 2       2          PE   10034191.0  Pulmonary embolism
# 3       3          GI          NaN                 NaN
# 4       4          ER          NaN                 NaN

# %%
trial_by_ae = pd.read_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/subset_adverse_events files/anxiety_subset_adverse_events.csv', index_col=0)

# %%
trial_by_ae.head()
# Out:
#         nct_id           id                                     adverse_events
# 1  NCT03315208  121187683.0  {relapsetosubstancesresultingininpatienttreatm...
# 2  NCT03315208  121187684.0  {relapsetosubstancesresultingininpatienttreatm...
# 3  NCT03315208  121187685.0  {relapsetosubstancesresultingininpatienttreatm...
# 4  NCT03315208  121187686.0  {relapsetosubstancesresultinginemergencydepart...
# 5  NCT03315208  121187687.0  {relapsetosubstancesresultinginemergencydepart...

# %%
unique_id = pd.DataFrame(trial_by_ae['id'].unique(), columns = ['id'])

# %%
unique_id.head()
# Out:
#             id
# 0  121187683.0
# 1  121187684.0
# 2  121187685.0
# 3  121187686.0
# 4  121187687.0

# %%
unique_ae_case = pd.DataFrame(trial_by_ae['adverse_events'].unique(), columns = ['lower'])
unique_ae_case['lower'] = unique_ae_case['lower'].str.slice(1,-1,1)

# %%
unique_ae_case.head()
# Out:
#                                                lower
# 0   relapsetosubstancesresultingininpatienttreatment
# 1  relapsetosubstancesresultinginemergencydepartm...
# 2  activesuicidalideationwithplanresultingininpat...
# 3  activesuicidalideationwithplanwithoutinpatient...
# 4  increaseinpsychoticsymptomsresultingininpatien...

# %%
unique_ae = unique_ae_case.merge(unique_ae, how='inner', on='lower')

# %%
unique_ae.shape, unique_id.shape, smq_mapped.shape, trial_by_ae.shape
# Out:
# ((2663, 2), (3863, 1), (101145, 4), (3930, 3))

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ## Sort for analysis

# %%
unique_ae.sort_values(by='adverse_event_term', key=lambda x: x.str.len(), inplace=True)

# %% [markdown]
# ## Drop duplicates and NaN values

# %%
unique_ae.drop_duplicates('lower', inplace=True)
unique_ae.dropna(axis=0, inplace=True)
unique_ae.reset_index(drop=True, inplace=True)
smq_mapped.drop('Row ID', axis=1, inplace=True)

# %%
trial_by_ae.dropna(axis=0, inplace=True)
trial_by_ae.reset_index(drop=True, inplace=True)

# %%
term_hits = pd.DataFrame(smq_mapped.dropna(axis=0))

# %%
unique_ae.shape, smq_mapped.shape, term_hits.shape, trial_by_ae.shape, unique_id.shape
# Out:
# ((677, 2), (101145, 3), (24767, 3), (3862, 3), (3863, 1))

# %%
unique_ae.head()
# Out:
#   lower adverse_event_term
# 0    gi                 GI
# 1   ear                ear
# 2   uri                Uri
# 3   gas                GAS
# 4   eye                eye

# %%
ae_lookup_df = unique_ae.merge(term_hits, how='inner', left_on='adverse_event_term', right_on='LLT/PT Term')

# %%
ae_lookup_df.head()
# Out:
#    lower adverse_event_term LLT/PT Term  LLT/PT Code          PT
# 0    gas                GAS         GAS   10017735.0  Flatulence
# 1   acne               ACNE        ACNE   10000496.0        Acne
# 2   rash               rash        rash   10037844.0        Rash
# 3   pica               Pica        Pica   10035001.0        Pica
# 4  death              DEATH       DEATH   10011906.0       Death

# %%
ae_lookup_df.shape
# Out:
# (127, 5)

# %% [markdown]
# ## Create Final Table

# %%
final_ae = pd.DataFrame(columns=ae_lookup_df['PT'].unique(), index=trial_by_ae['id'])

# %%
final_ae.shape
# Out:
# (3862, 113)

# %%
final_ae.head()
# Out:
#             Flatulence Acne Rash Pica Death Pyrexia Anger Oedema  \
# id
# 121187683.0        NaN  NaN  NaN  NaN   NaN     NaN   NaN    NaN
# 121187684.0        NaN  NaN  NaN  NaN   NaN     NaN   NaN    NaN
# 121187685.0        NaN  NaN  NaN  NaN   NaN     NaN   NaN    NaN
# 121187686.0        NaN  NaN  NaN  NaN   NaN     NaN   NaN    NaN
# 121187687.0        NaN  NaN  NaN  NaN   NaN     NaN   NaN    NaN
#
#             Neoplasm malignant Somnolence  ... Hyperemesis gravidarum  \
# id                                         ...
# 121187683.0                NaN        NaN  ...                    NaN
# 121187684.0                NaN        NaN  ...                    NaN
# 121187685.0                NaN        NaN  ...                    NaN
# 121187686.0                NaN        NaN  ...                    NaN
# 121187687.0                NaN        NaN  ...                    NaN
#
#             Self-injurious ideation Blood uric acid increased  \
# id
# 121187683.0                     NaN                       NaN
# 121187684.0                     NaN                       NaN
# 121187685.0                     NaN                       NaN
# 121187686.0                     NaN                       NaN
# 121187687.0                     NaN                       NaN
#
#             Blood bilirubin increased Mean cell volume decreased  \
# id
# 121187683.0                       NaN                        NaN
# 121187684.0                       NaN                        NaN
# 121187685.0                       NaN                        NaN
# 121187686.0                       NaN                        NaN
# 121187687.0                       NaN                        NaN
#
#             Musculoskeletal chest pain Blood cholesterol increased  \
# id
# 121187683.0                        NaN                         NaN
# 121187684.0                        NaN                         NaN
# 121187685.0                        NaN                         NaN
# 121187686.0                        NaN                         NaN
# 121187687.0                        NaN                         NaN
#
#             Generalised anxiety disorder White blood cells urine positive  \
# id
# 121187683.0                          NaN                              NaN
# 121187684.0                          NaN                              NaN
# 121187685.0                          NaN                              NaN
# 121187686.0                          NaN                              NaN
# 121187687.0                          NaN                              NaN
#
#             Glycosylated haemoglobin increased
# id
# 121187683.0                                NaN
# 121187684.0                                NaN
# 121187685.0                                NaN
# 121187686.0                                NaN
# 121187687.0                                NaN
#
# [5 rows x 113 columns]

# %%
for i in range(trial_by_ae.shape[0]):
  check = 0
  ind = trial_by_ae['id'][i]
  term = trial_by_ae['adverse_events'][i][1:-1]
  if (ae_lookup_df['lower'] == term).any():
    adverse_event = ae_lookup_df.loc[ae_lookup_df['lower'] == term]
    adverse_event = adverse_event['PT'].values[0]
    final_ae.loc[ind, adverse_event] = 1
    check = 1
  if check == 0:
    final_ae.drop(ind)

# %%
final_ae.shape
# Out:
# (3862, 113)

# %%
final_ae.dropna(axis=0, how='all', inplace=True)
final_ae.fillna(0, inplace=True)
final_ae.shape
# Out:
# (901, 113)

# %%
anxiety_ae_table = final_ae

# %%
anxiety_ae_table.to_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/Final AE Tables/anxiety_ae_table.csv')

# %% [markdown]
# # Bipolar Adverse Event Table Notebook

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

import os
import time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Read in Tables

# %%
unique_ae = pd.read_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/distinct_reported_events.csv')

# %%
smq_mapped = pd.read_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/smq_edited.csv')

# %%
smq_mapped.head()
# Out:
#    Row ID LLT/PT Term  LLT/PT Code                  PT
# 0       0           V          NaN                 NaN
# 1       1           K   10023271.0     Blood potassium
# 2       2          PE   10034191.0  Pulmonary embolism
# 3       3          GI          NaN                 NaN
# 4       4          ER          NaN                 NaN

# %%
trial_by_ae = pd.read_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/subset_adverse_events files/bipolar_subset_adverse_events.csv', index_col=0)

# %%
trial_by_ae.head()
# Out:
#         nct_id           id               adverse_events
# 1  NCT00811473  124611912.0                  {agitation}
# 2  NCT00811473  124611913.0                  {agitation}
# 3  NCT00811473  124611914.0  {socialstayhospitalisation}
# 4  NCT00811473  124611915.0  {socialstayhospitalisation}
# 5  NCT00811473  124611916.0            {bipolardisorder}

# %%
unique_id = pd.DataFrame(trial_by_ae['id'].unique(), columns = ['id'])

# %%
unique_id.head()
# Out:
#             id
# 0  124611912.0
# 1  124611913.0
# 2  124611914.0
# 3  124611915.0
# 4  124611916.0

# %%
unique_ae_case = pd.DataFrame(trial_by_ae['adverse_events'].unique(), columns = ['lower'])
unique_ae_case['lower'] = unique_ae_case['lower'].str.slice(1,-1,1)

# %%
unique_ae_case.head()
# Out:
#                        lower
# 0                  agitation
# 1  socialstayhospitalisation
# 2            bipolardisorder
# 3                 aggression
# 4         depressivesymptoms

# %%
unique_ae = unique_ae_case.merge(unique_ae, how='inner', on='lower')

# %%
unique_ae.shape, unique_id.shape, smq_mapped.shape, trial_by_ae.shape
# Out:
# ((4152, 2), (8226, 1), (101145, 4), (8242, 3))

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ## Sort for analysis

# %%
unique_ae.sort_values(by='adverse_event_term', key=lambda x: x.str.len(), inplace=True)

# %% [markdown]
# ## Drop duplicates and NaN values

# %%
unique_ae.drop_duplicates('lower', inplace=True)
unique_ae.dropna(axis=0, inplace=True)
unique_ae.reset_index(drop=True, inplace=True)
smq_mapped.drop('Row ID', axis=1, inplace=True)

# %%
trial_by_ae.dropna(axis=0, inplace=True)
trial_by_ae.reset_index(drop=True, inplace=True)

# %%
term_hits = pd.DataFrame(smq_mapped.dropna(axis=0))

# %%
unique_ae.shape, smq_mapped.shape, term_hits.shape, trial_by_ae.shape, unique_id.shape
# Out:
# ((1087, 2), (101145, 3), (24767, 3), (8225, 3), (8226, 1))

# %%
unique_ae.head()
# Out:
#   lower adverse_event_term
# 0   flu                FLU
# 1   uri                Uri
# 2  pain               Pain
# 3  coma               Coma
# 4  burn               burn

# %%
ae_lookup_df = unique_ae.merge(term_hits, how='inner', left_on='adverse_event_term', right_on='LLT/PT Term')

# %%
ae_lookup_df.head()
# Out:
#    lower adverse_event_term LLT/PT Term  LLT/PT Code         PT
# 0    flu                FLU         FLU   10016790.0  Influenza
# 1   coma               Coma        Coma   10010071.0       Coma
# 2  fever              fever       fever   10016558.0    Pyrexia
# 3  wound              Wound       Wound   10052428.0      Wound
# 4  cough              COUGH       COUGH   10011224.0      Cough

# %%
ae_lookup_df.shape
# Out:
# (275, 5)

# %% [markdown]
# ## Create Final Table

# %%
final_ae = pd.DataFrame(columns=ae_lookup_df['PT'].unique(), index=trial_by_ae['id'])

# %%
final_ae.shape
# Out:
# (8225, 236)

# %%
final_ae.head()
# Out:
#             Influenza Coma Pyrexia Wound Cough Anaemia Bezoar Hunger Seizure  \
# id
# 124611912.0       NaN  NaN     NaN   NaN   NaN     NaN    NaN    NaN     NaN
# 124611913.0       NaN  NaN     NaN   NaN   NaN     NaN    NaN    NaN     NaN
# 124611914.0       NaN  NaN     NaN   NaN   NaN     NaN    NaN    NaN     NaN
# 124611915.0       NaN  NaN     NaN   NaN   NaN     NaN    NaN    NaN     NaN
# 124611916.0       NaN  NaN     NaN   NaN   NaN     NaN    NaN    NaN     NaN
#
#             Empyema  ... Altered state of consciousness  \
# id                   ...
# 124611912.0     NaN  ...                            NaN
# 124611913.0     NaN  ...                            NaN
# 124611914.0     NaN  ...                            NaN
# 124611915.0     NaN  ...                            NaN
# 124611916.0     NaN  ...                            NaN
#
#             Transposition of the great vessels Wolff-Parkinson-White syndrome  \
# id
# 124611912.0                                NaN                            NaN
# 124611913.0                                NaN                            NaN
# 124611914.0                                NaN                            NaN
# 124611915.0                                NaN                            NaN
# 124611916.0                                NaN                            NaN
#
#             Disturbance in social behaviour Arteriosclerosis coronary artery  \
# id
# 124611912.0                             NaN                              NaN
# 124611913.0                             NaN                              NaN
# 124611914.0                             NaN                              NaN
# 124611915.0                             NaN                              NaN
# 124611916.0                             NaN                              NaN
#
#             Intervertebral disc degeneration  \
# id
# 124611912.0                              NaN
# 124611913.0                              NaN
# 124611914.0                              NaN
# 124611915.0                              NaN
# 124611916.0                              NaN
#
#             Lower respiratory tract infection  \
# id
# 124611912.0                               NaN
# 124611913.0                               NaN
# 124611914.0                               NaN
# 124611915.0                               NaN
# 124611916.0                               NaN
#
#             Blood pressure systolic decreased  \
# id
# 124611912.0                               NaN
# 124611913.0                               NaN
# 124611914.0                               NaN
# 124611915.0                               NaN
# 124611916.0                               NaN
#
#             Autonomic nervous system imbalance  \
# id
# 124611912.0                                NaN
# 124611913.0                                NaN
# 124611914.0                                NaN
# 124611915.0                                NaN
# 124611916.0                                NaN
#
#             Complication associated with device
# id
# 124611912.0                                 NaN
# 124611913.0                                 NaN
# 124611914.0                                 NaN
# 124611915.0                                 NaN
# 124611916.0                                 NaN
#
# [5 rows x 236 columns]

# %%
for i in range(trial_by_ae.shape[0]):
  check = 0
  ind = trial_by_ae['id'][i]
  term = trial_by_ae['adverse_events'][i][1:-1]
  if (ae_lookup_df['lower'] == term).any():
    adverse_event = ae_lookup_df.loc[ae_lookup_df['lower'] == term]
    adverse_event = adverse_event['PT'].values[0]
    final_ae.loc[ind, adverse_event] = 1
    check = 1
  if check == 0:
    final_ae.drop(ind)

# %%
final_ae.shape
# Out:
# (8225, 236)

# %%
final_ae.dropna(axis=0, how='all', inplace=True)
final_ae.fillna(0, inplace=True)
final_ae.shape
# Out:
# (2048, 236)

# %%
bipolar_ae_table = final_ae

# %%
bipolar_ae_table.to_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/Final AE Tables/bipolar_ae_table.csv')

# %% [markdown]
# # Alzheimers Adverse Event Table Notebook

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

import os
import time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### Read in Tables

# %%
trial_by_ae = pd.read_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/subset_adverse_events files/alzheimers_subset_adverse_events.csv', index_col=0)

# %%
trial_by_ae
# Out:
#             nct_id           id                            adverse_events
# 1      NCT02585232  121987318.0  {hospitalizationsandemergencyroomvisits}
# 2      NCT02585232  121987319.0  {hospitalizationsandemergencyroomvisits}
# 3      NCT02585232  121987320.0                               {housefire}
# 4      NCT02585232  121987321.0                               {housefire}
# 5      NCT02585232  121987322.0              {duplicatemeasurescollected}
# ...            ...          ...                                       ...
# 60571  NCT01699503  119237906.0                {incidentseveredepression}
# 60572  NCT01699503  119237907.0                {incidentseveredepression}
# 60573  NCT01699503  119237908.0                   {incidentsevereanxiety}
# 60574  NCT01699503  119237909.0                   {incidentsevereanxiety}
# 60575  NCT01439555          NaN                                       NaN
#
# [60575 rows x 3 columns]

# %%
trial_by_ae_1 = trial_by_ae.iloc[:30287]
trial_by_ae_2 = trial_by_ae.iloc[30287:]

# %% [markdown]
# ### complete for first half of AD ae table

# %%
unique_ae = pd.read_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/distinct_reported_events.csv')

# %%
smq_mapped = pd.read_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/smq_edited.csv')

# %%
smq_mapped.head()
# Out:
#    Row ID LLT/PT Term  LLT/PT Code                  PT
# 0       0           V          NaN                 NaN
# 1       1           K   10023271.0     Blood potassium
# 2       2          PE   10034191.0  Pulmonary embolism
# 3       3          GI          NaN                 NaN
# 4       4          ER          NaN                 NaN

# %%
trial_by_ae_1.head()
# Out:
#         nct_id           id                            adverse_events
# 1  NCT02585232  121987318.0  {hospitalizationsandemergencyroomvisits}
# 2  NCT02585232  121987319.0  {hospitalizationsandemergencyroomvisits}
# 3  NCT02585232  121987320.0                               {housefire}
# 4  NCT02585232  121987321.0                               {housefire}
# 5  NCT02585232  121987322.0              {duplicatemeasurescollected}

# %%
unique_id = pd.DataFrame(trial_by_ae_1['id'].unique(), columns = ['id'])

# %%
unique_id.head()
# Out:
#             id
# 0  121987318.0
# 1  121987319.0
# 2  121987320.0
# 3  121987321.0
# 4  121987322.0

# %%
unique_ae_case = pd.DataFrame(trial_by_ae_1['adverse_events'].unique(), columns = ['lower'])
unique_ae_case['lower'] = unique_ae_case['lower'].str.slice(1,-1,1)

# %%
unique_ae_case.head()
# Out:
#                                     lower
# 0  hospitalizationsandemergencyroomvisits
# 1                               housefire
# 2              duplicatemeasurescollected
# 3                          anginaunstable
# 4                     atrialfribrillation

# %%
unique_ae = unique_ae_case.merge(unique_ae, how='inner', on='lower')

# %%
unique_ae.shape, unique_id.shape, smq_mapped.shape, trial_by_ae_1.shape
# Out:
# ((8346, 2), (30280, 1), (101145, 4), (30287, 3))

# %% [markdown]
# #### Data Cleaning

# %% [markdown]
# #### Sort for analysis

# %%
unique_ae.sort_values(by='adverse_event_term', key=lambda x: x.str.len(), inplace=True)

# %% [markdown]
# #### Drop duplicates and NaN values

# %%
unique_ae.drop_duplicates('lower', inplace=True)
unique_ae.dropna(axis=0, inplace=True)
unique_ae.reset_index(drop=True, inplace=True)
smq_mapped.drop('Row ID', axis=1, inplace=True)

# %%
trial_by_ae_1.dropna(axis=0, inplace=True)
trial_by_ae_1.reset_index(drop=True, inplace=True)

# %%
term_hits = pd.DataFrame(smq_mapped.dropna(axis=0))

# %%
unique_ae.shape, smq_mapped.shape, term_hits.shape, trial_by_ae_1.shape, unique_id.shape
# Out:
# ((2129, 2), (101145, 3), (24767, 3), (30279, 3), (30280, 1))

# %%
unique_ae.head()
# Out:
#   lower adverse_event_term
# 0  fall               fall
# 1  gout               Gout
# 2  rash               Rash
# 3  mass               MASS
# 4  cold               Cold

# %%
ae_lookup_df = unique_ae.merge(term_hits, how='inner', left_on='adverse_event_term', right_on='LLT/PT Term')

# %%
ae_lookup_df.head()
# Out:
#    lower adverse_event_term LLT/PT Term  LLT/PT Code                    PT
# 0    flu                FLU         FLU   10016790.0             Influenza
# 1    dvt                dvt         dvt   10013877.0  Deep vein thrombosis
# 2   cyst               cyst        cyst   10011732.0                  Cyst
# 3   itch               Itch        Itch   10023082.0              Pruritus
# 4  hives              HIVES       HIVES   10020197.0             Urticaria

# %%
ae_lookup_df.shape
# Out:
# (774, 5)

# %% [markdown]
# #### Create Final Table

# %%
final_ae_1 = pd.DataFrame(columns=ae_lookup_df['PT'].unique(), index=trial_by_ae_1['id'])

# %%
final_ae_1.shape
# Out:
# (30279, 606)

# %%
final_ae_1.head()
# Out:
#             Influenza Deep vein thrombosis Cyst Pruritus Urticaria Shock  \
# id
# 121987318.0       NaN                  NaN  NaN      NaN       NaN   NaN
# 121987319.0       NaN                  NaN  NaN      NaN       NaN   NaN
# 121987320.0       NaN                  NaN  NaN      NaN       NaN   NaN
# 121987321.0       NaN                  NaN  NaN      NaN       NaN   NaN
# 121987322.0       NaN                  NaN  NaN      NaN       NaN   NaN
#
#             Eczema Ataxia Gait inability Sepsis  ... Nasal cavity cancer  \
# id                                               ...
# 121987318.0    NaN    NaN            NaN    NaN  ...                 NaN
# 121987319.0    NaN    NaN            NaN    NaN  ...                 NaN
# 121987320.0    NaN    NaN            NaN    NaN  ...                 NaN
# 121987321.0    NaN    NaN            NaN    NaN  ...                 NaN
# 121987322.0    NaN    NaN            NaN    NaN  ...                 NaN
#
#             Lower respiratory tract infection bacterial  \
# id
# 121987318.0                                         NaN
# 121987319.0                                         NaN
# 121987320.0                                         NaN
# 121987321.0                                         NaN
# 121987322.0                                         NaN
#
#             Tongue neoplasm malignant stage unspecified  \
# id
# 121987318.0                                         NaN
# 121987319.0                                         NaN
# 121987320.0                                         NaN
# 121987321.0                                         NaN
# 121987322.0                                         NaN
#
#             Oesophageal squamous cell carcinoma stage IV  \
# id
# 121987318.0                                          NaN
# 121987319.0                                          NaN
# 121987320.0                                          NaN
# 121987321.0                                          NaN
# 121987322.0                                          NaN
#
#             Neovascular age-related macular degeneration  \
# id
# 121987318.0                                          NaN
# 121987319.0                                          NaN
# 121987320.0                                          NaN
# 121987321.0                                          NaN
# 121987322.0                                          NaN
#
#             Documented hypersensitivity to administered product  \
# id
# 121987318.0                                                NaN
# 121987319.0                                                NaN
# 121987320.0                                                NaN
# 121987321.0                                                NaN
# 121987322.0                                                NaN
#
#             Neuropsychiatric symptoms  \
# id
# 121987318.0                       NaN
# 121987319.0                       NaN
# 121987320.0                       NaN
# 121987321.0                       NaN
# 121987322.0                       NaN
#
#             Amyloid related imaging abnormality-oedema/effusion  \
# id
# 121987318.0                                                NaN
# 121987319.0                                                NaN
# 121987320.0                                                NaN
# 121987321.0                                                NaN
# 121987322.0                                                NaN
#
#             Drug reaction with eosinophilia and systemic symptoms  \
# id
# 121987318.0                                                NaN
# 121987319.0                                                NaN
# 121987320.0                                                NaN
# 121987321.0                                                NaN
# 121987322.0                                                NaN
#
#             Amyloid related imaging abnormality-microhaemorrhages and haemosiderin deposits
# id
# 121987318.0                                                NaN
# 121987319.0                                                NaN
# 121987320.0                                                NaN
# 121987321.0                                                NaN
# 121987322.0                                                NaN
#
# [5 rows x 606 columns]

# %%
for i in range(trial_by_ae_1.shape[0]):
  check = 0
  ind = trial_by_ae_1['id'][i]
  term = trial_by_ae_1['adverse_events'][i][1:-1]
  if (ae_lookup_df['lower'] == term).any():
    adverse_event = ae_lookup_df.loc[ae_lookup_df['lower'] == term]
    adverse_event = adverse_event['PT'].values[0]
    final_ae_1.loc[ind, adverse_event] = 1
    check = 1
  if check == 0:
    final_ae_1.drop(ind)

# %%
final_ae_1.shape
# Out:
# (30279, 606)

# %%
final_ae_1.dropna(axis=0, how='all', inplace=True)
final_ae_1.fillna(0, inplace=True)
final_ae_1.shape
# Out:
# (9073, 606)

# %%
alzheimers_ae_table_1 = final_ae_1

# %%
unique_ae = pd.read_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/distinct_reported_events.csv')

# %%
smq_mapped = pd.read_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/smq_edited.csv')

# %%
smq_mapped.head()
# Out:
#    Row ID LLT/PT Term  LLT/PT Code                  PT
# 0       0           V          NaN                 NaN
# 1       1           K   10023271.0     Blood potassium
# 2       2          PE   10034191.0  Pulmonary embolism
# 3       3          GI          NaN                 NaN
# 4       4          ER          NaN                 NaN

# %%
trial_by_ae_2.head()
# Out:
#             nct_id           id    adverse_events
# 30288  NCT01369225  118572540.0            {fall}
# 30289  NCT01369225  118572541.0  {ligamentsprain}
# 30290  NCT01369225  118572542.0  {ligamentsprain}
# 30291  NCT01369225  118572543.0  {ligamentsprain}
# 30292  NCT01369225  118572544.0  {ligamentsprain}

# %%
unique_id = pd.DataFrame(trial_by_ae_2['id'].unique(), columns = ['id'])

# %%
unique_id.head()
# Out:
#             id
# 0  118572540.0
# 1  118572541.0
# 2  118572542.0
# 3  118572543.0
# 4  118572544.0

# %%
unique_ae_case = pd.DataFrame(trial_by_ae_2['adverse_events'].unique(), columns = ['lower'])
unique_ae_case['lower'] = unique_ae_case['lower'].str.slice(1,-1,1)

# %%
unique_ae_case.head()
# Out:
#                        lower
# 0                       fall
# 1             ligamentsprain
# 2  spinalcompressionfracture
# 3              wristfracture
# 4             abdominalbruit

# %%
unique_ae = unique_ae_case.merge(unique_ae, how='inner', on='lower')

# %%
unique_ae.shape, unique_id.shape, smq_mapped.shape, trial_by_ae_2.shape
# Out:
# ((8065, 2), (30282, 1), (101145, 4), (30288, 3))

# %% [markdown]
# ## complete for second half of AD ae table

# %% [markdown]
# #### Data Cleaning

# %% [markdown]
# #### Sort for analysis

# %%
unique_ae.sort_values(by='adverse_event_term', key=lambda x: x.str.len(), inplace=True)

# %% [markdown]
# #### Drop duplicates and NaN values

# %%
unique_ae.drop_duplicates('lower', inplace=True)
unique_ae.dropna(axis=0, inplace=True)
unique_ae.reset_index(drop=True, inplace=True)
smq_mapped.drop('Row ID', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-c0df0348435b> in <module>()
#       2 unique_ae.dropna(axis=0, inplace=True)
#       3 unique_ae.reset_index(drop=True, inplace=True)
# ----> 4 smq_mapped.drop('Row ID', axis=1, inplace=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['Row ID'] not found in axis"

# %%
trial_by_ae_2.dropna(axis=0, inplace=True)
trial_by_ae_2.reset_index(drop=True, inplace=True)

# %%
term_hits = pd.DataFrame(smq_mapped.dropna(axis=0))

# %%
unique_ae.shape, smq_mapped.shape, term_hits.shape, trial_by_ae_2.shape, unique_id.shape
# Out:
# ((2031, 2), (101145, 3), (24767, 3), (30281, 3), (30282, 1))

# %%
unique_ae.head()
# Out:
#   lower adverse_event_term
# 0  fall               fall
# 1  gout               Gout
# 2  rash               Rash
# 3  mass               MASS
# 4  cold               Cold

# %%
ae_lookup_df = unique_ae.merge(term_hits, how='inner', left_on='adverse_event_term', right_on='LLT/PT Term')

# %%
ae_lookup_df.head()
# Out:
#     lower adverse_event_term LLT/PT Term  LLT/PT Code      PT
# 0    pain               pain        pain   10033371.0    Pain
# 1    coma               Coma        Coma   10010071.0    Coma
# 2   wound              Wound       Wound   10052428.0   Wound
# 3   rigor              rigor       rigor   10039175.0  Chills
# 4  goitre             goitre      goitre   10018498.0  Goitre

# %%
ae_lookup_df.shape
# Out:
# (711, 5)

# %% [markdown]
# #### Create Final Table

# %%
final_ae_2 = pd.DataFrame(columns=ae_lookup_df['PT'].unique(), index=trial_by_ae_2['id'])

# %%
final_ae_2.shape
# Out:
# (30281, 593)

# %%
final_ae_2.head()
# Out:
#             Pain Coma Wound Chills Goitre Abulia Tremor Nausea Anaemia  \
# id
# 118572540.0  NaN  NaN   NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 118572541.0  NaN  NaN   NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 118572542.0  NaN  NaN   NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 118572543.0  NaN  NaN   NaN    NaN    NaN    NaN    NaN    NaN     NaN
# 118572544.0  NaN  NaN   NaN    NaN    NaN    NaN    NaN    NaN     NaN
#
#             Amyloid related imaging abnormality-oedema/effusion  ...  \
# id                                                               ...
# 118572540.0                                                NaN   ...
# 118572541.0                                                NaN   ...
# 118572542.0                                                NaN   ...
# 118572543.0                                                NaN   ...
# 118572544.0                                                NaN   ...
#
#             Lip neoplasm malignant stage unspecified  \
# id
# 118572540.0                                      NaN
# 118572541.0                                      NaN
# 118572542.0                                      NaN
# 118572543.0                                      NaN
# 118572544.0                                      NaN
#
#             Gastrointestinal arteriovenous malformation  \
# id
# 118572540.0                                         NaN
# 118572541.0                                         NaN
# 118572542.0                                         NaN
# 118572543.0                                         NaN
# 118572544.0                                         NaN
#
#             Anticoagulation drug level above therapeutic  \
# id
# 118572540.0                                          NaN
# 118572541.0                                          NaN
# 118572542.0                                          NaN
# 118572543.0                                          NaN
# 118572544.0                                          NaN
#
#             Hyperglycaemic hyperosmolar nonketotic syndrome  \
# id
# 118572540.0                                             NaN
# 118572541.0                                             NaN
# 118572542.0                                             NaN
# 118572543.0                                             NaN
# 118572544.0                                             NaN
#
#             Superficial siderosis of central nervous system  \
# id
# 118572540.0                                             NaN
# 118572541.0                                             NaN
# 118572542.0                                             NaN
# 118572543.0                                             NaN
# 118572544.0                                             NaN
#
#             Dementia of the Alzheimer's type, with delusions  \
# id
# 118572540.0                                              NaN
# 118572541.0                                              NaN
# 118572542.0                                              NaN
# 118572543.0                                              NaN
# 118572544.0                                              NaN
#
#             Brief psychotic disorder without marked stressors  \
# id
# 118572540.0                                               NaN
# 118572541.0                                               NaN
# 118572542.0                                               NaN
# 118572543.0                                               NaN
# 118572544.0                                               NaN
#
#             Magnetic resonance imaging head abnormal  \
# id
# 118572540.0                                      NaN
# 118572541.0                                      NaN
# 118572542.0                                      NaN
# 118572543.0                                      NaN
# 118572544.0                                      NaN
#
#             Mucoid degeneration of the anterior cruciate ligament  \
# id
# 118572540.0                                                NaN
# 118572541.0                                                NaN
# 118572542.0                                                NaN
# 118572543.0                                                NaN
# 118572544.0                                                NaN
#
#             Amyloid related imaging abnormality-microhaemorrhages and haemosiderin deposits
# id
# 118572540.0                                                NaN
# 118572541.0                                                NaN
# 118572542.0                                                NaN
# 118572543.0                                                NaN
# 118572544.0                                                NaN
#
# [5 rows x 593 columns]

# %%
for i in range(trial_by_ae_2.shape[0]):
  check = 0
  ind = trial_by_ae_2['id'][i]
  term = trial_by_ae_2['adverse_events'][i][1:-1]
  if (ae_lookup_df['lower'] == term).any():
    adverse_event = ae_lookup_df.loc[ae_lookup_df['lower'] == term]
    adverse_event = adverse_event['PT'].values[0]
    final_ae_2.loc[ind, adverse_event] = 1
    check = 1
  if check == 0:
    final_ae_2.drop(ind)

# %%
final_ae_2.shape
# Out:
# (30281, 593)

# %%
final_ae_2.dropna(axis=0, how='all', inplace=True)
final_ae_2.fillna(0, inplace=True)
final_ae_2.shape
# Out:
# (8724, 593)

# %%
alzheimers_ae_table_2 = final_ae_2

# %%
frames = [alzheimers_ae_table_1, alzheimers_ae_table_2]
  
alzheimers_ae_table = pd.concat(frames)

# %%
alzheimers_ae_table.to_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/Final AE Tables/alzheimers_ae_table.csv')

# %% [markdown]
# # Parkinson's Adverse Event Table Notebook

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

import os
import time

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Read in Tables

# %%
unique_ae = pd.read_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/distinct_reported_events.csv')

# %%
smq_mapped = pd.read_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/smq_edited.csv')

# %%
smq_mapped.head()

# %%
trial_by_ae = pd.read_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/subset_adverse_events files/parkinsons_subset_adverse_events.csv', index_col=0)

# %%
trial_by_ae.head()

# %%
unique_id = pd.DataFrame(trial_by_ae['id'].unique(), columns = ['id'])

# %%
unique_id.head()

# %%
unique_ae_case = pd.DataFrame(trial_by_ae['adverse_events'].unique(), columns = ['lower'])
unique_ae_case['lower'] = unique_ae_case['lower'].str.slice(1,-1,1)

# %%
unique_ae_case.head()

# %%
unique_ae = unique_ae_case.merge(unique_ae, how='inner', on='lower')

# %%
unique_ae.shape, unique_id.shape, smq_mapped.shape, trial_by_ae.shape

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ## Sort for analysis

# %%
unique_ae.sort_values(by='adverse_event_term', key=lambda x: x.str.len(), inplace=True)

# %% [markdown]
# ## Drop duplicates and NaN values

# %%
unique_ae.drop_duplicates('lower', inplace=True)
unique_ae.dropna(axis=0, inplace=True)
unique_ae.reset_index(drop=True, inplace=True)
smq_mapped.drop('Row ID', axis=1, inplace=True)

# %%
trial_by_ae.dropna(axis=0, inplace=True)
trial_by_ae.reset_index(drop=True, inplace=True)

# %%
term_hits = pd.DataFrame(smq_mapped.dropna(axis=0))

# %%
unique_ae.shape, smq_mapped.shape, term_hits.shape, trial_by_ae.shape, unique_id.shape

# %%
unique_ae.head()

# %%
ae_lookup_df = unique_ae.merge(term_hits, how='inner', left_on='adverse_event_term', right_on='LLT/PT Term')

# %%
ae_lookup_df.head()

# %%
ae_lookup_df.shape

# %% [markdown]
# ## Create Final Table

# %%
final_ae = pd.DataFrame(columns=ae_lookup_df['PT'].unique(), index=trial_by_ae['id'])

# %%
final_ae.shape

# %%
final_ae.head()

# %%
for i in range(trial_by_ae.shape[0]):
  check = 0
  ind = trial_by_ae['id'][i]
  term = trial_by_ae['adverse_events'][i][1:-1]
  if (ae_lookup_df['lower'] == term).any():
    adverse_event = ae_lookup_df.loc[ae_lookup_df['lower'] == term]
    adverse_event = adverse_event['PT'].values[0]
    final_ae.loc[ind, adverse_event] = 1
    check = 1
  if check == 0:
    final_ae.drop(ind)

# %%
final_ae.shape
# Out:
# (26591, 616)

# %%
final_ae.dropna(axis=0, how='all', inplace=True)
final_ae.fillna(0, inplace=True)
final_ae.shape
# Out:
# (6625, 616)

# %%
parkinsons_ae_table = final_ae

# %%
parkinsons_ae_table.to_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/Final AE Tables/parkinsons_ae_table.csv')

# %% [markdown]
# # ALS Adverse Event Table Notebook

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

import os
import time

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Read in Tables

# %%
unique_ae = pd.read_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/distinct_reported_events.csv')

# %%
smq_mapped = pd.read_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/smq_edited.csv')

# %%
smq_mapped.head()

# %%
trial_by_ae = pd.read_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/subset_adverse_events files/als_subset_adverse_events.csv', index_col=0)

# %%
trial_by_ae.head()

# %%
unique_id = pd.DataFrame(trial_by_ae['id'].unique(), columns = ['id'])

# %%
unique_id.head()

# %%
unique_ae_case = pd.DataFrame(trial_by_ae['adverse_events'].unique(), columns = ['lower'])
unique_ae_case['lower'] = unique_ae_case['lower'].str.slice(1,-1,1)

# %%
unique_ae_case.head()

# %%
unique_ae = unique_ae_case.merge(unique_ae, how='inner', on='lower')

# %%
unique_ae.shape, unique_id.shape, smq_mapped.shape, trial_by_ae.shape

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ## Sort for analysis

# %%
unique_ae.sort_values(by='adverse_event_term', key=lambda x: x.str.len(), inplace=True)

# %% [markdown]
# ## Drop duplicates and NaN values

# %%
unique_ae.drop_duplicates('lower', inplace=True)
unique_ae.dropna(axis=0, inplace=True)
unique_ae.reset_index(drop=True, inplace=True)
smq_mapped.drop('Row ID', axis=1, inplace=True)

# %%
trial_by_ae.dropna(axis=0, inplace=True)
trial_by_ae.reset_index(drop=True, inplace=True)

# %%
term_hits = pd.DataFrame(smq_mapped.dropna(axis=0))

# %%
unique_ae.shape, smq_mapped.shape, term_hits.shape, trial_by_ae.shape, unique_id.shape

# %%
unique_ae.head()

# %%
ae_lookup_df = unique_ae.merge(term_hits, how='inner', left_on='adverse_event_term', right_on='LLT/PT Term')

# %%
ae_lookup_df.head()

# %%
ae_lookup_df.shape

# %% [markdown]
# ## Create Final Table

# %%
final_ae = pd.DataFrame(columns=ae_lookup_df['PT'].unique(), index=trial_by_ae['id'])

# %%
final_ae.shape

# %%
final_ae.head()

# %%
for i in range(trial_by_ae.shape[0]):
  check = 0
  ind = trial_by_ae['id'][i]
  term = trial_by_ae['adverse_events'][i][1:-1]
  if (ae_lookup_df['lower'] == term).any():
    adverse_event = ae_lookup_df.loc[ae_lookup_df['lower'] == term]
    adverse_event = adverse_event['PT'].values[0]
    final_ae.loc[ind, adverse_event] = 1
    check = 1
  if check == 0:
    final_ae.drop(ind)

# %%
final_ae.shape

# %%
final_ae.dropna(axis=0, how='all', inplace=True)
final_ae.fillna(0, inplace=True)
final_ae.shape

# %%
als_ae_table = final_ae

# %%
als_ae_table.to_csv('/content/drive/MyDrive/HIDS510/Collab Notebooks/Adverse Events Table/Final AE Tables/als_ae_table.csv')
